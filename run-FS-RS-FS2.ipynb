# %% [markdown]
# # A notebook to run
# the simulation scripts, and to analyze them further

# %%
import scipy as sp
import numpy as np
import matplotlib

import matplotlib.pyplot as plt

import os
import re as re
import matplotlib.patches as mpatches
import pandas as pd

from neurodsp.spectral import compute_spectrum
from neurodsp.filt import filter_signal

# %load_ext lab_black
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
# %run FS-RS-FS2.py
# Out:
# clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
# ld: library not found for -lstdc++
# clang: error: linker command failed with exit code 1 (use -v to see invocation)
# WARNING    Cannot use Cython, a test compilation failed: command 'g++' failed with exit status 1 (LinkError) [brian2.codegen.runtime.cython_rt.cython_rt.failed_compile_test]
# INFO       Cannot use compiled code, falling back to the numpy code generation target. Note that this will likely be slower than using compiled code. Set the code generation to numpy manually to avoid this message:
# prefs.codegen.target = "numpy" [brian2.devices.device.codegen_fallback]
# INFO       No numerical integration method specified for group 'neurongroup_1', using method 'euler' (took 0.14s, trying other methods took 0.24s). [brian2.stateupdaters.base.method_choice]
# INFO       No numerical integration method specified for group 'neurongroup_2', using method 'euler' (took 0.02s, trying other methods took 0.20s). [brian2.stateupdaters.base.method_choice]
# INFO       No numerical integration method specified for group 'neurongroup', using method 'euler' (took 0.01s, trying other methods took 0.18s). [brian2.stateupdaters.base.method_choice]

# %%
plt.figure(figsize=(10, 2))
plt.plot(spikemonStimulus.t, spikemonStimulus.i, ".", markersize=0.1, color="black")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
plt.title("Stimulus")
# Out:
# Text(0.5, 1.0, 'Stimulus')

# %%
plt.figure(figsize=(10, 4))
plt.plot(ratemonStimulus.t, ratemonStimulus.rate / Hz, color="black")
plt.xlabel("Time (s)")
plt.ylabel("Rate (Hz)")
plt.title("Stimulus")
# Out:
# Text(0.5, 1.0, 'Stimulus')

# %%
plt.figure(figsize=(10, 2))
plt.plot(spikemonIosc.t, spikemonIosc.i, ".", markersize=1, color="black")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
plt.title("Osc (ING)")
# Out:
# Text(0.5, 1.0, 'Osc (ING)')

# %%
plt.figure(figsize=(10, 6))
# plt.title("Simulated LFP", fontsize=30)
plt.plot(Phase_time, LFP_thatOverLapsFileteredOne, color="grey", label="Raw LFP")
plt.plot(
    Phase_time,
    LFPFiltered_main,
    linewidth=1,
    color="black",
    label="Filtered LFP "
    + str(int(lowcut_main))
    + "-"
    + str(int(highcut_main))
    + " Hz",
)
plt.plot(
    Phase_time, Envelope_main, linewidth=1, color="purple", label="Hilbert Envelope"
)
plt.legend(bbox_to_anchor=(1, 0.5))
plt.xlabel("Time (s)")
plt.ylabel("LFP (AU)")
# Out:
# Text(0, 0.5, 'LFP (AU)')

# %%
plt.figure(figsize=(10, 4))
plt.plot(ratemonIosc.t, ratemonIosc.rate / Hz, color="black")
plt.xlabel("Time (s)")
plt.ylabel("Rate (Hz)")
plt.title("Osc (ING)")
# Out:
# Text(0.5, 1.0, 'Osc (ING)')

# %%
fig, axes = plt.subplots(2, 1, sharey=True, figsize=(10, 4))
axes[0].plot(ratemonE.t, ratemonE.rate / Hz, color="red", label="E")
axes[0].set_xlabel("Time (s)")
axes[0].set_ylabel("Rate (Hz)")
axes[1].plot(ratemonI.t, ratemonI.rate / Hz, color="blue", label="I")
axes[1].set_xlabel("Time (s)")
axes[1].set_ylabel("Rate (Hz)")
# Out:
# Text(0, 0.5, 'Rate (Hz)')

# %%
# plt.plot(spikemonIosc.t, spikemonIosc.i, ".", markersize=1, color="black")
fig, axes = plt.subplots(2, 1, sharey=False, figsize=(10, 8))
axes[0].plot(spikemonE.t, spikemonE.i, ".", markersize=1, color="red", label="E")
axes[0].set_xlabel("Time (s)")
axes[0].set_ylabel("Neuron")
axes[1].plot(spikemonI.t, spikemonI.i, ".", markersize=1, color="blue", label="I")
axes[1].set_xlabel("Time (s)")
axes[1].set_ylabel("Neuron")
# Out:
# Text(0, 0.5, 'Neuron')
